# %%
#Explanation of my visualizations #1 and #2 - Chan Evan:

# %% [markdown]
# Visualization #1 - minimum delay by station
# For each visualization, describe and justify:
#     > What software did you use to create your data visualization?
# I used Python and some libraries/packages: matplotlib, etc.
#     > Who is your intended audience?
# TTC Users! General public! I tried to make it simple!
#     > What information or message are you trying to convey with your visualization?
# I am trying to convey the minimum delay (in time) per station. I am trying to show which stations have shorter delays and which ones have long ones!
#     > What aspects of design did you consider when making your visualization? How did you apply them? With what elements of your plots?
# I tried to particularily make the visualization easy to interpret and apparent. You can clearly see with the scales I used how some delay times are significantly more greater than others. I also wanted to clearly label the plots
#     > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
# The data visualization is reproducible given that I used all the same data from one CSV file. If any user downloads my code and CSV file, they will get the same results!
#     > How did you ensure that your data visualization is accessible?
# Even though there was lots of data and routes, I wanted to make sure that the font was large enough! This was my main concern. My only concern was the overwhelming routes of buses!
#     > Who are the individuals and communities who might be impacted by your visualization?
# Individuals commuting on the TTC regularily and researchers and regulators trying to reduce TTC delays and better understand where the congestion exists!
#     > How did you choose which features of your chosen dataset to include or exclude from your visualization?
# I looked for salient quantitative features that are measurable and more reliant, i.e., time delays
#     > What ‘underwater labour’ contributed to your final data visualization product?
# Mostly data organizing and better understanding the CSV file! Otherwise, the commands were straightforward for generalizing visualizations.
# - This assignment is intentionally open-ended - you are free to create static or dynamic data visualizations, maps, or whatever form of data visualization you think best communicates your information to your audience of choice!
# - Total word count should not exceed **(as a maximum) 1000 words**

# %% [markdown]
# Visualization #2 - average minimum by day
# For each visualization, describe and justify:
#     > What software did you use to create your data visualization?
# I used Python and some libraries/packages: matplotlib, etc.
#     > Who is your intended audience?
# In this case, I also think TTC users and researchers would appreciate this. Knowing which days are busiest, might be useful for travellers!
#     > What information or message are you trying to convey with your visualization?
# i am trying to show which days have on average longer and shorter delays!
#     > What aspects of design did you consider when making your visualization? How did you apply them? With what elements of your plots?
# I mostly considered how to make the days "make sense." I used a bar chart to seperate the days, but I also ordered them horizontally in ordinal order... from less delays to more delays to make it more understandable from the get go!
#     > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
# Again, similar to visualization #1. The data visualization if reproducible given that I used all the same data from one CSV file. If any user downloads my code and CSV file, they will get the same results!
#     > How did you ensure that your data visualization is accessible?
# Mostly enlarging the font/bars and making the general increasing trends of the delays obvious so it is immediately apprent to the viewer
#     > Who are the individuals and communities who might be impacted by your visualization?
# I think mostly TTC users and researchers!
#     > How did you choose which features of your chosen dataset to include or exclude from your visualization?
# I chose days, because they are ordinal categorical variables and average delays by day. I think these are all "boxable" and quantifiable metrics that are useful for TTC users. I chose metrics and features based on quantifiability and usefulness!
#     > What ‘underwater labour’ contributed to your final data visualization product?
# Mostly data wrangling as demonstrated in my code!
# - This assignment is intentionally open-ended - you are free to create static or dynamic data visualizations, maps, or whatever form of data visualization you think best communicates your information to your audience of choice!
# - Total word count should not exceed **(as a maximum) 1000 words**
